# %%
# %pip install wikipedia

# %%
import wikipedia as wkp
wkp.set_lang('pt')

# %%
pesquisa = wkp.search('Fluminense FC', results = 1)
pesquisa
# Out:
# ['Fluminense Football Club']

# %%
wikipage = wkp.page(pesquisa[0])

# %%
wikipage.title
# Out:
# 'Fluminense Football Club'

# %%
wikipage.url
# Out:
# 'https://pt.wikipedia.org/wiki/Fluminense_Football_Club'

# %%
content = wikipage.content

# %%
print(content)
# Out:
# O Fluminense Football Club, popularmente referido por seus apelidos Nense, Fluzão e Flu, é uma agremiação poliesportiva e cultural sediada no bairro de Laranjeiras, Zona Sul da cidade do Rio de Janeiro, no Brasil, fundada em 21 de julho de 1902. É uma sociedade civil de caráter desportivo, que tem como principal atividade o futebol.
# ...

# %%
print(len(wikipage.images))
# Out:
# 210

# %%
wikipage.images[0]
# Out:
# 'https://upload.wikimedia.org/wikipedia/commons/b/b2/1D-Estadual.png'
